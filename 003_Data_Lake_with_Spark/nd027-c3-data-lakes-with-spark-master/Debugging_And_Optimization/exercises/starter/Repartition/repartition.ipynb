# %%
# %run -i 'repartition.py'
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~/Desktop/Udacity_Data_Engineering_Nanodegree/003_Data_Lake_with_Spark/nd027-c3-data-lakes-with-spark-master/Debugging_And_Optimization/exercises/starter/Repartition/repartition.py in <module>
#      21
#      22 if __name__ == "__main__":
# ---> 23     repartition()
#
# ~/Desktop/Udacity_Data_Engineering_Nanodegree/003_Data_Lake_with_Spark/nd027-c3-data-lakes-with-spark-master/Debugging_And_Optimization/exercises/starter/Repartition/repartition.py in repartition()
#       5
#       6     # TODO Path to your file
# ----> 7     df = spark.read.format('./parking_violation.csv').load()
#       8
#       9
#
# ~/Desktop/Udacity_Data_Engineering_Nanodegree/udacity_dend/lib/python3.7/site-packages/pyspark/sql/readwriter.py in load(self, path, format, schema, **options)
# ...
